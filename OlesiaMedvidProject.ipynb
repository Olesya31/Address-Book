# %% [markdown]
# <a href="https://colab.research.google.com/github/Olesya31/Address-Book/blob/main/OlesiaMedvidProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read csv file
df = pd.read_csv('/content/GDP (current US$).csv')
print(df.shape)
df.head()
# Out:
# (266, 66)
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.008272e+10  2.050945e+10  2.235043e+10  2.675866e+10
# 2  NY.GDP.MKTP.CD  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 3  NY.GDP.MKTP.CD  1.040428e+10  1.112805e+10  1.194335e+10  1.267652e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2012          2013          2014  \
# ...

# %%
#deleting unnecessary columns
df.drop(columns = df.columns[1:55], inplace=True)
df.drop(columns = df.columns[-1], inplace=True)
df.head()
# Out:
#                   Country Name          2011          2012          2013  \
# 0                        Aruba  2.549721e+09  2.534637e+09  2.727850e+09
# 1  Africa Eastern and Southern  9.430000e+11  9.510000e+11  9.640000e+11
# 2                  Afghanistan  1.780511e+10  1.990732e+10  2.014640e+10
# 3   Africa Western and Central  6.710000e+11  7.280000e+11  8.210000e+11
# 4                       Angola  1.120000e+11  1.280000e+11  1.370000e+11
#
#            2014          2015          2016          2017          2018  \
# 0  2.790849e+09  2.962905e+09  2.983637e+09  3.092430e+09  3.202189e+09
# 1  9.850000e+11  9.200000e+11  8.730000e+11  9.850000e+11  1.010000e+12
# 2  2.049713e+10  1.913421e+10  1.811656e+10  1.875347e+10  1.805323e+10
# 3  8.650000e+11  7.610000e+11  6.910000e+11  6.840000e+11  7.420000e+11
# 4  1.460000e+11  1.160000e+11  1.010000e+11  1.220000e+11  1.010000e+11
#
#            2019          2020
# 0           NaN           NaN
# 1  1.010000e+12  9.210000e+11
# ...

# %%
#selection countries of EU
EU = ["Austria", "Belgium", "Bulgaria", "Croatia", "Cyprus", "Czech Republic", "Denmark", "Estonia", "Finland", "France", "Germany", "Greece", "Hungary", "Ireland", "Italy", "Latvia", "Lithuania", "Luxembourg", "Malta", "Netherlands", "Poland", "Portugal", "Romania", "Slovak Republic", "Slovenia", "Spain", "Sweden"]
df1= df[df["Country Name"].isin(EU)]
print(df1.shape)
df1.head()
# Out:
# (27, 11)
#       Country Name          2011          2012          2013          2014  \
# 14         Austria  4.320000e+11  4.090000e+11  4.300000e+11  4.430000e+11
# 17         Belgium  5.230000e+11  4.960000e+11  5.220000e+11  5.350000e+11
# 21        Bulgaria  5.767824e+10  5.430086e+10  5.581014e+10  5.708201e+10
# 53          Cyprus  2.756547e+10  2.497851e+10  2.390087e+10  2.315685e+10
# 54  Czech Republic  2.300000e+11  2.090000e+11  2.120000e+11  2.090000e+11
#
#             2015          2016          2017          2018          2019  \
# 14  3.820000e+11  3.960000e+11  4.170000e+11  4.550000e+11  4.450000e+11
# 17  4.620000e+11  4.760000e+11  5.030000e+11  5.430000e+11  5.350000e+11
# 21  5.078200e+10  5.395390e+10  5.919945e+10  6.636342e+10  6.891542e+10
# 53  1.984240e+10  2.095344e+10  2.287083e+10  2.552267e+10  2.575836e+10
# 54  1.880000e+11  1.960000e+11  2.190000e+11  2.490000e+11  2.520000e+11
#
#             2020
# 14  4.330000e+11
# 17  5.220000e+11
# ...

# %%
#changing view of the table(wide to long)
df1 = df1.melt(id_vars=['Country Name'], value_vars=["2011",	"2012",	"2013",	"2014",	"2015",	"2016",	"2017",	"2018",	"2019", "2020"],
              var_name='Year', value_name='GDP')
df1.head()
# Out:
#      Country Name  Year           GDP
# 0         Austria  2011  4.320000e+11
# 1         Belgium  2011  5.230000e+11
# 2        Bulgaria  2011  5.767824e+10
# 3          Cyprus  2011  2.756547e+10
# 4  Czech Republic  2011  2.300000e+11

# %%
#changing view of the table(long to wide)
df2 = df1.pivot(index="Country Name", columns=["Year"])
df2.head()
# Out:
#                        GDP                                            \
# Year                  2011          2012          2013          2014
# Country Name
# Austria       4.320000e+11  4.090000e+11  4.300000e+11  4.430000e+11
# Belgium       5.230000e+11  4.960000e+11  5.220000e+11  5.350000e+11
# Bulgaria      5.767824e+10  5.430086e+10  5.581014e+10  5.708201e+10
# Croatia       6.316991e+10  5.719235e+10  5.888908e+10  5.833029e+10
# Cyprus        2.756547e+10  2.497851e+10  2.390087e+10  2.315685e+10
#
#                                                                       \
# Year                  2015          2016          2017          2018
# Country Name
# Austria       3.820000e+11  3.960000e+11  4.170000e+11  4.550000e+11
# Belgium       4.620000e+11  4.760000e+11  5.030000e+11  5.430000e+11
# Bulgaria      5.078200e+10  5.395390e+10  5.919945e+10  6.636342e+10
# Croatia       5.016319e+10  5.229516e+10  5.621443e+10  6.224787e+10
# ...

# %%
#GDP of EU mean
df3 = df1.groupby('Year').mean()
df3.rename(columns = {'GDP':'GDP EU (mean)'}, inplace = True)
df3
# Out:
#       GDP EU (mean)
# Year
# 2011   5.836685e+11
# 2012   5.419503e+11
# 2013   5.665624e+11
# 2014   5.797242e+11
# 2015   5.023809e+11
# 2016   5.144736e+11
# 2017   5.469025e+11
# 2018   5.917080e+11
# 2019   5.810949e+11
# 2020   5.665259e+11

# %%
df1.plot(kind='bar',x='Country Name',y='GDP')

# %%
#GDP Germany
df_ger = df1[df1['Country Name']=="Germany"].groupby('Year').sum()
df_ger.rename(columns = {'GDP':'GDP Germany'}, inplace = True)
df_ger
# Out:
#        GDP Germany
# Year
# 2011  3.750000e+12
# 2012  3.530000e+12
# 2013  3.730000e+12
# 2014  3.890000e+12
# 2015  3.360000e+12
# 2016  3.470000e+12
# 2017  3.690000e+12
# 2018  3.980000e+12
# 2019  3.890000e+12
# 2020  3.850000e+12

# %%
#GDP of EU and Germany
df_ger_eumean = df_ger.merge(df3, on=["Year"])
df_ger_eumean
# Out:
#        GDP Germany  GDP EU (mean)
# Year
# 2011  3.750000e+12   5.836685e+11
# 2012  3.530000e+12   5.419503e+11
# 2013  3.730000e+12   5.665624e+11
# 2014  3.890000e+12   5.797242e+11
# 2015  3.360000e+12   5.023809e+11
# 2016  3.470000e+12   5.144736e+11
# 2017  3.690000e+12   5.469025e+11
# 2018  3.980000e+12   5.917080e+11
# 2019  3.890000e+12   5.810949e+11
# 2020  3.850000e+12   5.665259e+11

# %%
df_ger_eumean.plot()

# %%
df1.groupby('Country Name')['GDP'].nunique().plot(kind='bar')
dfe_ger = df1[df1['Country Name']=="Germany"].groupby('Year').sum()
dfe_gerplt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-d8558d7dcf0a> in <module>()
#       1 df1.groupby('Country Name')['GDP'].nunique().plot(kind='bar')
#       2 dfe_ger = df1[df1['Country Name']=="Germany"].groupby('Year').sum()
# ----> 3 dfe_gerplt.show()
#
# NameError: name 'dfe_gerplt' is not defined

# %%
sns.catplot(kind='bar', data=df1, col='Year', x='Country Name', y='GDP', order=sorted(df1.Year.unique()),
            col_order=sorted(df1.Year.unique()), estimator=sum, ci=None, height=5.5)

# %%
df_ger.plot()

# %%
#GDP Germany
df_ger = df1[df1['Country Name']=="Germany"].groupby('Year').sum()
df_ger["GDP"].plot()

# %%
df1.plot.scatter(x="Year", y="GDP", alpha=0.5)

# %%
df_ger.plot.box()

# %%
xs = df_ger.plot.area(figsize=(16, 10), subplots=True)

# %%
df_ger.plot.area()

# %%
#reading a file "Final consumption expenditure (current US$)"
dfc = pd.read_csv("/content/Final consumption expenditure (current US$).csv")
print(dfc.shape)
dfc.head()
# Out:
# (266, 66)
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                 Indicator Name  Indicator Code         1960  \
# 0  Final consumption expenditure (current US$)  NE.CON.TOTL.CD          NaN
# 1  Final consumption expenditure (current US$)  NE.CON.TOTL.CD          NaN
# 2  Final consumption expenditure (current US$)  NE.CON.TOTL.CD  466666655.6
# 3  Final consumption expenditure (current US$)  NE.CON.TOTL.CD          NaN
# 4  Final consumption expenditure (current US$)  NE.CON.TOTL.CD          NaN
#
#           1961         1962         1963         1964         1965  ...  \
# 0          NaN          NaN          NaN          NaN          NaN  ...
# 1          NaN          NaN          NaN          NaN          NaN  ...
# ...

# %%
#deleting unnecessary columns
dfc.drop(columns = dfc.columns[1:55], inplace=True)
dfc.drop(columns = dfc.columns[-1], inplace=True)
dfc.head()
# Out:
#                   Country Name          2011          2012          2013  \
# 0                        Aruba  2.230168e+09  2.294972e+09  2.317821e+09
# 1  Africa Eastern and Southern  7.360220e+11  7.598730e+11  7.767050e+11
# 2                  Afghanistan           NaN           NaN           NaN
# 3   Africa Western and Central  5.060590e+11  5.104260e+11  6.478020e+11
# 4                       Angola  5.837463e+10  6.819103e+10  8.089778e+10
#
#            2014          2015          2016          2017          2018  \
# 0  2.322533e+09  2.328514e+09  2.327950e+09  2.416911e+09  2.537791e+09
# 1  7.793170e+11  7.439720e+11  7.045450e+11  7.843890e+11  8.126430e+11
# 2           NaN           NaN           NaN           NaN           NaN
# 3  6.699780e+11  6.304230e+11  5.817860e+11  5.653070e+11  5.985750e+11
# 4  9.098620e+10  8.037909e+10  7.069212e+10  8.563117e+10  6.774046e+10
#
#            2019          2020
# 0           NaN           NaN
# 1  8.131180e+11  7.463940e+11
# ...

# %%
#selecting EU countries
EU = ["Austria", "Belgium", "Bulgaria", "Croatia", "Cyprus", "Czech Republic", "Denmark", "Estonia", "Finland", "France", "Germany", "Greece", "Hungary", "Ireland", "Italy", "Latvia", "Lithuania", "Luxembourg", "Malta", "Netherlands", "Poland", "Portugal", "Romania", "Slovak Republic", "Slovenia", "Spain", "Sweden"]
#df["Country Name"].unique()
dfc1= dfc[dfc["Country Name"].isin(EU)]
print(dfc1.shape)
dfc1.head()
# Out:
# (27, 11)
#       Country Name          2011          2012          2013          2014  \
# 14         Austria  3.163230e+11  3.001750e+11  3.165290e+11  3.239690e+11
# 17         Belgium  3.955960e+11  3.783020e+11  4.006000e+11  4.071380e+11
# 21        Bulgaria  4.527264e+10  4.420080e+10  4.440271e+10  4.542492e+10
# 53          Cyprus  2.340318e+10  2.140914e+10  2.043390e+10  1.979831e+10
# 54  Czech Republic  1.584630e+11  1.438540e+11  1.466820e+11  1.416440e+11
#
#             2015          2016          2017          2018          2019  \
# 14  2.767170e+11  2.846580e+11  3.004210e+11  3.242840e+11  3.160610e+11
# 17  3.465390e+11  3.549220e+11  3.745830e+11  4.067640e+11  3.981470e+11
# 21  3.966454e+10  4.107974e+10  4.492145e+10  5.059922e+10  5.221987e+10
# 53  1.660905e+10  1.694403e+10  1.824461e+10  2.025418e+10  2.047133e+10
# 54  1.242430e+11  1.302230e+11  1.445280e+11  1.664430e+11  1.676530e+11
#
#             2020
# 14  3.090190e+11
# 17  3.884360e+11
# ...

# %%
#changing view of the table(wide to long)
dfc1 = dfc1.melt(id_vars=['Country Name'], value_vars=["2011",	"2012",	"2013",	"2014",	"2015",	"2016",	"2017",	"2018",	"2019", "2020"],
              var_name='Year', value_name='Consumption')
dfc1.head()
# Out:
#      Country Name  Year   Consumption
# 0         Austria  2011  3.163230e+11
# 1         Belgium  2011  3.955960e+11
# 2        Bulgaria  2011  4.527264e+10
# 3          Cyprus  2011  2.340318e+10
# 4  Czech Republic  2011  1.584630e+11

# %%
#group by year
dfc2 = dfc1.groupby("Year").sum()
dfc2
# Out:
#        Consumption
# Year
# 2011  1.207131e+13
# 2012  1.124684e+13
# 2013  1.171889e+13
# 2014  1.188213e+13
# 2015  1.014702e+13
# 2016  1.037406e+13
# 2017  1.095184e+13
# 2018  1.181835e+13
# 2019  1.154709e+13
# 2020  1.134404e+13

# %%
#selection Germany
dfc_ger = dfc1[dfc1['Country Name']=="Germany"].groupby('Year').sum()
dfc_ger
# Out:
#        Consumption
# Year
# 2011  2.754120e+12
# 2012  2.616570e+12
# 2013  2.770030e+12
# 2014  2.839480e+12
# 2015  2.439680e+12
# 2016  2.521050e+12
# 2017  2.655520e+12
# 2018  2.860770e+12
# 2019  2.807760e+12
# 2020  2.812720e+12

# %%
#reading the file "Exports of goods and services"
dfe = pd.read_csv('/content/Exports of goods and services (BoP, current US$).csv')
print(dfe.shape)
dfe.head()
# Out:
# (266, 66)
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                      Indicator Name  Indicator Code  1960  \
# 0  Exports of goods and services (BoP, current US$)  BX.GSR.GNFS.CD   NaN
# 1  Exports of goods and services (BoP, current US$)  BX.GSR.GNFS.CD   NaN
# 2  Exports of goods and services (BoP, current US$)  BX.GSR.GNFS.CD   NaN
# 3  Exports of goods and services (BoP, current US$)  BX.GSR.GNFS.CD   NaN
# 4  Exports of goods and services (BoP, current US$)  BX.GSR.GNFS.CD   NaN
#
#    1961  1962  1963  1964  1965  ...          2012          2013  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  3.151006e+09  2.162037e+09
# 1   NaN   NaN   NaN   NaN   NaN  ...  2.868610e+11  2.868130e+11
# ...

# %%
#deleting unnecessary columns
dfe.drop(columns = dfe.columns[1:55], inplace=True)
dfe.drop(columns = dfe.columns[-1], inplace=True)
dfe.head()
# Out:
#                   Country Name          2011          2012          2013  \
# 0                        Aruba  6.861117e+09  3.151006e+09  2.162037e+09
# 1  Africa Eastern and Southern  2.942930e+11  2.868610e+11  2.868130e+11
# 2                  Afghanistan  3.057794e+09  2.328861e+09  1.383202e+09
# 3   Africa Western and Central  1.962960e+11  1.948600e+11  1.966590e+11
# 4                       Angola  6.804254e+10  7.187328e+10  6.956222e+10
#
#            2014          2015          2016          2017          2018  \
# 0  2.299629e+09  2.437131e+09  2.344278e+09  2.305573e+09  2.557266e+09
# 1  2.775390e+11  2.226730e+11  2.112210e+11  2.395030e+11  2.639560e+11
# 2  1.985367e+09  1.417301e+09  1.136013e+09  1.152896e+09  1.609472e+09
# 3  1.796610e+11  1.265530e+11  1.155920e+11  1.406500e+11  1.659640e+11
# 4  6.085123e+10  3.443729e+10  2.829977e+10  3.559804e+10  4.138889e+10
#
#            2019          2020
# 0  2.561692e+09  1.449742e+09
# 1  2.495340e+11  2.086190e+11
# ...

# %%
#selection of EU countries
EU = ["Austria", "Belgium", "Bulgaria", "Croatia", "Cyprus", "Czech Republic", "Denmark", "Estonia", "Finland", "France", "Germany", "Greece", "Hungary", "Ireland", "Italy", "Latvia", "Lithuania", "Luxembourg", "Malta", "Netherlands", "Poland", "Portugal", "Romania", "Slovak Republic", "Slovenia", "Spain", "Sweden"]
#df["Country Name"].unique()
dfe = dfe[dfe["Country Name"].isin(EU)]
print(dfe.shape)
dfe.head()
# Out:
# (27, 11)
#       Country Name          2011          2012          2013          2014  \
# 14         Austria  2.294740e+11  2.180950e+11  2.288770e+11  2.360940e+11
# 17         Belgium  4.288550e+11  4.072890e+11  4.265080e+11  4.363720e+11
# 21        Bulgaria  3.403111e+10  3.266415e+10  3.598016e+10  3.691565e+10
# 53          Cyprus  1.476176e+10  1.378403e+10  1.466912e+10  1.526767e+10
# 54  Czech Republic  1.628210e+11  1.583610e+11  1.609780e+11  1.717010e+11
#
#             2015          2016          2017          2018          2019  \
# 14  2.023990e+11  2.070070e+11  2.253720e+11  2.522050e+11  2.465460e+11
# 17  3.596840e+11  3.779410e+11  4.181580e+11  4.511440e+11  4.401320e+11
# 21  3.247514e+10  3.449955e+10  3.987337e+10  4.352158e+10  4.404121e+10
# 53  1.390459e+10  1.478178e+10  1.700047e+10  1.914495e+10  1.946091e+10
# 54  1.514460e+11  1.552900e+11  1.732350e+11  1.916940e+11  1.865450e+11
#
#             2020
# 14  2.229450e+11
# 17  4.175210e+11
# ...

# %%
#changing view of the table(wide to long)
dfe1 = dfe.melt(id_vars=['Country Name'], value_vars=["2011",	"2012",	"2013",	"2014",	"2015",	"2016",	"2017",	"2018",	"2019", "2020"],
              var_name='Year', value_name='Exports')
dfe1.head()
# Out:
#      Country Name  Year       Exports
# 0         Austria  2011  2.294740e+11
# 1         Belgium  2011  4.288550e+11
# 2        Bulgaria  2011  3.403111e+10
# 3          Cyprus  2011  1.476176e+10
# 4  Czech Republic  2011  1.628210e+11

# %%
##changing view of the table(long to wide)
dfe2 = dfe1.pivot(index="Country Name", columns=["Year"])
dfe2.head()
# Out:
#                    Exports                                            \
# Year                  2011          2012          2013          2014
# Country Name
# Austria       2.294740e+11  2.180950e+11  2.288770e+11  2.360940e+11
# Belgium       4.288550e+11  4.072890e+11  4.265080e+11  4.363720e+11
# Bulgaria      3.403111e+10  3.266415e+10  3.598016e+10  3.691565e+10
# Croatia       2.437344e+10  2.339413e+10  2.348476e+10  2.498985e+10
# Cyprus        1.476176e+10  1.378403e+10  1.466912e+10  1.526767e+10
#
#                                                                       \
# Year                  2015          2016          2017          2018
# Country Name
# Austria       2.023990e+11  2.070070e+11  2.253720e+11  2.522050e+11
# Belgium       3.596840e+11  3.779410e+11  4.181580e+11  4.511440e+11
# Bulgaria      3.247514e+10  3.449955e+10  3.987337e+10  4.352158e+10
# Croatia       2.299759e+10  2.468908e+10  2.801779e+10  3.071692e+10
# ...

# %%
#group by year
dfe3 = dfe1.groupby("Year").mean()
dfe3
# Out:
#            Exports
# Year
# 2011  2.522074e+11
# 2012  2.436689e+11
# 2013  2.563784e+11
# 2014  2.658389e+11
# 2015  2.376274e+11
# 2016  2.412889e+11
# 2017  2.659131e+11
# 2018  2.921502e+11
# 2019  2.876190e+11
# 2020  2.655186e+11

# %%
#selection of Germany
dfe_ger = dfe1[dfe1['Country Name']=="Germany"].groupby('Year').sum()
dfe_ger
# Out:
#            Exports
# Year
# 2011  1.686060e+12
# 2012  1.629430e+12
# 2013  1.699810e+12
# 2014  1.773620e+12
# 2015  1.575250e+12
# 2016  1.598250e+12
# 2017  1.741500e+12
# 2018  1.881510e+12
# 2019  1.813190e+12
# 2020  1.673710e+12

# %%
#contatenate GDP, Exports and Consumption of Germany
df_ = df_ger.merge(dfe_ger, on=["Year"])
df_ = df_.merge(dfc_ger, on=["Year"])
df_.head()
# Out:
#                GDP       Exports   Consumption
# Year
# 2011  3.750000e+12  1.686060e+12  2.754120e+12
# 2012  3.530000e+12  1.629430e+12  2.616570e+12
# 2013  3.730000e+12  1.699810e+12  2.770030e+12
# 2014  3.890000e+12  1.773620e+12  2.839480e+12
# 2015  3.360000e+12  1.575250e+12  2.439680e+12

# %%
df_.plot()

# %%
plt.scatter(df_['GDP'], df_['Exports'])
np.corrcoef(df_['GDP'], df_['Exports'])[0,1]
# Out:
# 0.8932472129033738

# %%
plt.scatter(df_['GDP'], df_['Consumption'])
np.corrcoef(df_['GDP'], df_['Consumption'])[0,1]
# Out:
# 0.9777529543786266

# %%
df_.corr()
# Out:
#                   GDP   Exports  Consumption
# GDP          1.000000  0.893247     0.977753
# Exports      0.893247  1.000000     0.816817
# Consumption  0.977753  0.816817     1.000000

# %%
df_.plot(x="GDP", y="Exports", kind="scatter")

# %%
plt.scatter(df_['GDP'], df_['Exports'])
plt.xlabel('GDP')
plt.ylabel('Exports');

# %%
#GDP, Exports and Consumption of Germany
df_.plot(kind="bar")

# %%
#GDP, Exports and Consumption of Germany
df_ger.plot(kind="bar")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn.metrics import r2_score

# %%
plt.scatter(df_['GDP'], df_['Exports'])

# %%
plt.scatter(df_['Consumption'], df_['Exports'])

# %%
X = df_[['GDP']]
y = df_['Exports']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((8, 1), (2, 1), (8,), (2,))

# %%
clf = LinearRegression()
clf.fit(X_train , y_train)
train_score = clf.score(X_train , y_train)
train_score
# Out:
# 0.782442082342103

# %%
print(clf.coef_)
print(clf.intercept_)
# Out:
# [0.42485212]
# 131063569826.55542

# %%
y_pred = clf.predict(X_test)

# %%
test_score = r2_score(y_test , y_pred)
test_score
# Out:
# 0.8965063588733188

# %%
plt.scatter(df_['GDP'], df_['Exports'])
plt.plot(X_test, y_pred, color="red", linewidth=1)

# %%
#reading the file "GDP per capita"
df_cap = pd.read_csv('/content/GDP per capita (current US$).csv')
print(df_cap.shape)
df_cap.head()
# Out:
# (266, 66)
#                   Country Name Country Code                Indicator Name  \
# 0                        Aruba          ABW  GDP per capita (current US$)
# 1  Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                  Afghanistan          AFG  GDP per capita (current US$)
# 3   Africa Western and Central          AFW  GDP per capita (current US$)
# 4                       Angola          AGO  GDP per capita (current US$)
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# 0  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
# 1  NY.GDP.PCAP.CD  153.494439  152.873313  162.413188  189.506170  168.816995
# 2  NY.GDP.PCAP.CD   59.773234   59.860900   58.458009   78.706429   82.095307
# 3  NY.GDP.PCAP.CD  107.932233  113.081647  118.831107  123.442888  131.854402
# 4  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
#deleting unnecessary columns
df_cap.drop(columns = df_cap.columns[1:55], inplace=True)
df_cap.drop(columns = df_cap.columns[-1], inplace=True)
df_cap.head()
# Out:
#                   Country Name          2011          2012          2013  \
# 0                        Aruba  24985.013920  24712.493260  26441.619940
# 1  Africa Eastern and Southern   1770.736230   1736.166560   1713.899299
# 2                  Afghanistan    591.190030    638.845852    624.315454
# 3   Africa Western and Central   1862.308267   1965.118485   2157.481149
# 4                       Angola   4615.468219   5100.097027   5254.881126
#
#            2014          2015          2016          2017          2018  \
# 0  26893.011510  28396.908420  28452.170610  29350.805020  30253.279360
# 1   1703.596298   1549.037940   1431.778723   1573.063386   1574.978648
# 2    614.223342    556.007221    512.012778    516.679862    485.668419
# 3   2212.853135   1894.310195   1673.835527   1613.473553   1704.139603
# 4   5408.411700   4166.979833   3506.073128   4095.810057   3289.643995
#
#           2019         2020
# 0          NaN          NaN
# 1  1530.059177  1359.618224
# ...

# %%
#selection of EU countries
EU = ["Austria", "Belgium", "Bulgaria", "Croatia", "Cyprus", "Czech Republic", "Denmark", "Estonia", "Finland", "France", "Germany", "Greece", "Hungary", "Ireland", "Italy", "Latvia", "Lithuania", "Luxembourg", "Malta", "Netherlands", "Poland", "Portugal", "Romania", "Slovak Republic", "Slovenia", "Spain", "Sweden"]
df_cap1= df_cap[df_cap["Country Name"].isin(EU)]
print(df_cap1.shape)
df_cap1.head()
# Out:
# (27, 11)
#       Country Name          2011          2012         2013          2014  \
# 14         Austria  51442.276250  48564.917340  50731.12725  51786.377170
# 17         Belgium  47410.566930  44670.560680  46757.95186  47764.071510
# 21        Bulgaria   7849.165283   7432.478766   7681.93462   7901.785876
# 53          Cyprus  32396.385740  28912.156940  27729.19270  27163.332970
# 54  Czech Republic  21871.266080  19870.801210  20133.16914  19890.919910
#
#             2015          2016          2017          2018          2019  \
# 14  44195.817590  45307.587860  47429.158460  51486.575500  50114.401110
# 17  41008.296720  42012.622720  44198.482390  47542.769520  46591.491610
# 21   7074.681023   7569.478815   8366.293221   9446.700772   9879.268533
# 53  23408.336680  24605.920830  26608.875090  29334.110930  29206.076720
# 54  17829.698320  18575.232030  20636.199950  23419.735610  23660.148810
#
#            2020
# 14  48588.65938
# 17  45205.33594
# 21  10079.20338
# ...

# %%
#changing view of the table(wide to long)
df_cap2 = df_cap1.melt(id_vars=['Country Name'], value_vars=["2011",	"2012",	"2013",	"2014",	"2015",	"2016",	"2017",	"2018",	"2019", "2020"],
              var_name='Year', value_name='GDP per capita')
df_cap2.head()
# Out:
#      Country Name  Year  GDP per capita
# 0         Austria  2011    51442.276250
# 1         Belgium  2011    47410.566930
# 2        Bulgaria  2011     7849.165283
# 3          Cyprus  2011    32396.385740
# 4  Czech Republic  2011    21871.266080

# %%
#selection of Germany
df_cap_ger = df_cap2[df_cap2['Country Name']=="Germany"].groupby('Year').sum()
df_cap_ger.rename(columns = {'GDP per capita':'Germany'}, inplace = True)
df_cap_ger
# Out:
#           Germany
# Year
# 2011  46705.89580
# 2012  43855.85447
# 2013  46298.92292
# 2014  48023.86998
# 2015  41103.25644
# 2016  42136.12079
# 2017  44652.58917
# 2018  47973.60762
# 2019  46794.89929
# 2020  46252.68930

# %%
#selection France
df_cap_fr = df_cap2[df_cap2['Country Name']=="France"].groupby('Year').sum()
df_cap_fr.rename(columns = {'GDP per capita':'France'}, inplace = True)
df_cap_fr
# Out:
#            France
# Year
# 2011  43848.10605
# 2012  40872.36246
# 2013  42605.04438
# 2014  43068.54872
# 2015  36652.92231
# 2016  37062.53357
# 2017  38781.04949
# 2018  41592.79590
# 2019  40578.64429
# 2020  39037.12263

# %%
#concatenation Germany and France
df_cap_gerfr = df_cap_ger.merge(df_cap_fr, on=["Year"])
df_cap_gerfr
# Out:
#           Germany       France
# Year
# 2011  46705.89580  43848.10605
# 2012  43855.85447  40872.36246
# 2013  46298.92292  42605.04438
# 2014  48023.86998  43068.54872
# 2015  41103.25644  36652.92231
# 2016  42136.12079  37062.53357
# 2017  44652.58917  38781.04949
# 2018  47973.60762  41592.79590
# 2019  46794.89929  40578.64429
# 2020  46252.68930  39037.12263

# %%
#selection Romania
df_cap_ro = df_cap2[df_cap2['Country Name']=="Romania"].groupby('Year').sum()
df_cap_ro.rename(columns = {'GDP per capita':'Romania'}, inplace = True)
df_cap_ro
# Out:
#            Romania
# Year
# 2011   9099.217539
# 2012   8507.104775
# 2013   9547.852151
# 2014  10043.677450
# 2015   8969.148921
# 2016   9548.587403
# 2017  10807.009170
# 2018  12398.981980
# 2019  12899.346110
# 2020  12915.243050

# %%
#concatenation Romania to Germany and France
df_cap_gerfrro = df_cap_gerfr.merge(df_cap_ro, on=["Year"])
df_cap_gerfrro
# Out:
#           Germany       France       Romania
# Year
# 2011  46705.89580  43848.10605   9099.217539
# 2012  43855.85447  40872.36246   8507.104775
# 2013  46298.92292  42605.04438   9547.852151
# 2014  48023.86998  43068.54872  10043.677450
# 2015  41103.25644  36652.92231   8969.148921
# 2016  42136.12079  37062.53357   9548.587403
# 2017  44652.58917  38781.04949  10807.009170
# 2018  47973.60762  41592.79590  12398.981980
# 2019  46794.89929  40578.64429  12899.346110
# 2020  46252.68930  39037.12263  12915.243050

# %%
#selection Denmark
df_cap_de = df_cap2[df_cap2['Country Name']=="Denmark"].groupby('Year').sum()
df_cap_de.rename(columns = {'GDP per capita':'Denmark'}, inplace = True)
df_cap_de
# Out:
#           Denmark
# Year
# 2011  61753.64713
# 2012  58507.50805
# 2013  61191.19370
# 2014  62548.98473
# 2015  53254.85637
# 2016  54663.99837
# 2017  57610.09818
# 2018  61591.92887
# 2019  59775.73510
# 2020  61063.31643

# %%
#concatenation Denmark to other countries
df_cap_gerfrrode = df_cap_gerfrro.merge(df_cap_de, on=["Year"])
df_cap_gerfrrode
# Out:
#           Germany       France       Romania      Denmark
# Year
# 2011  46705.89580  43848.10605   9099.217539  61753.64713
# 2012  43855.85447  40872.36246   8507.104775  58507.50805
# 2013  46298.92292  42605.04438   9547.852151  61191.19370
# 2014  48023.86998  43068.54872  10043.677450  62548.98473
# 2015  41103.25644  36652.92231   8969.148921  53254.85637
# 2016  42136.12079  37062.53357   9548.587403  54663.99837
# 2017  44652.58917  38781.04949  10807.009170  57610.09818
# 2018  47973.60762  41592.79590  12398.981980  61591.92887
# 2019  46794.89929  40578.64429  12899.346110  59775.73510
# 2020  46252.68930  39037.12263  12915.243050  61063.31643

# %%
#selection Hungary
df_cap_hu = df_cap2[df_cap2['Country Name']=="Hungary"].groupby('Year').sum()
df_cap_hu.rename(columns = {'GDP per capita':'Hungary'}, inplace = True)
df_cap_hu
# Out:
#           Hungary
# Year
# 2011  14240.25750
# 2012  12989.18028
# 2013  13719.95054
# 2014  14298.83367
# 2015  12720.71202
# 2016  13107.37791
# 2017  14623.69665
# 2018  16427.37276
# 2019  16735.65978
# 2020  15980.10823

# %%
#concatenation Hungary to other countries
df_cap_gerfrrodehu = df_cap_gerfrrode.merge(df_cap_hu, on=["Year"])
df_cap_gerfrrodehu
# Out:
#           Germany       France       Romania      Denmark      Hungary
# Year
# 2011  46705.89580  43848.10605   9099.217539  61753.64713  14240.25750
# 2012  43855.85447  40872.36246   8507.104775  58507.50805  12989.18028
# 2013  46298.92292  42605.04438   9547.852151  61191.19370  13719.95054
# 2014  48023.86998  43068.54872  10043.677450  62548.98473  14298.83367
# 2015  41103.25644  36652.92231   8969.148921  53254.85637  12720.71202
# 2016  42136.12079  37062.53357   9548.587403  54663.99837  13107.37791
# 2017  44652.58917  38781.04949  10807.009170  57610.09818  14623.69665
# 2018  47973.60762  41592.79590  12398.981980  61591.92887  16427.37276
# 2019  46794.89929  40578.64429  12899.346110  59775.73510  16735.65978
# 2020  46252.68930  39037.12263  12915.243050  61063.31643  15980.10823

# %%
df_cap_gerfr.plot()

# %%
#EU mean
df_cap2_mean = df_cap2.groupby("Year").mean()
df_cap2_mean.rename(columns = {'GDP per capita':'EU mean'}, inplace = True)
df_cap2_mean
# Out:
#            EU mean
# Year
# 2011  34575.438221
# 2012  32302.857139
# 2013  33815.799041
# 2014  34594.422285
# 2015  30321.113945
# 2016  31041.162491
# 2017  33074.962983
# 2018  35944.284163
# 2019  35423.081452
# 2020  35093.815745

# %%
#concatenation EU mean to other counries
df_cap_gerfrrodehu_mean = df_cap_gerfrrodehu.merge(df_cap2_mean, on=["Year"])
df_cap_gerfrrodehu_mean
# Out:
#           Germany       France       Romania      Denmark      Hungary  \
# Year
# 2011  46705.89580  43848.10605   9099.217539  61753.64713  14240.25750
# 2012  43855.85447  40872.36246   8507.104775  58507.50805  12989.18028
# 2013  46298.92292  42605.04438   9547.852151  61191.19370  13719.95054
# 2014  48023.86998  43068.54872  10043.677450  62548.98473  14298.83367
# 2015  41103.25644  36652.92231   8969.148921  53254.85637  12720.71202
# 2016  42136.12079  37062.53357   9548.587403  54663.99837  13107.37791
# 2017  44652.58917  38781.04949  10807.009170  57610.09818  14623.69665
# 2018  47973.60762  41592.79590  12398.981980  61591.92887  16427.37276
# 2019  46794.89929  40578.64429  12899.346110  59775.73510  16735.65978
# 2020  46252.68930  39037.12263  12915.243050  61063.31643  15980.10823
#
#            EU mean
# Year
# 2011  34575.438221
# 2012  32302.857139
# 2013  33815.799041
# 2014  34594.422285
# 2015  30321.113945
# 2016  31041.162491
# 2017  33074.962983
# ...

# %%
df_cap_gerfrrodehu_mean.plot()

# %%
#GDP per capita Germany
df_cap_ger.plot(kind="bar")
